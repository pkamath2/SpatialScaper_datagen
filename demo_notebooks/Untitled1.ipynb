# %%
from IPython.display import Audio, display
import matplotlib.pyplot as plt
import librosa
import numpy as np

# %%
ir_file = '/soundspaces-binaural_rirs-mp3d.part-1/kEZ7cmS4wCh/90/1045_1045.wav'
ir_file = '/scratch/work/marl/datasets/soundspaces/download/ambisonic_rirs/mp3d/D7G3Y4RVNrH/irs/69_56.wav'
# ! ls /soundspaces-binaural_rirs-mp3d.part-1/kEZ7cmS4wCh/90/1045_1045.wav

# %%
ir_aud, sr = librosa.load(ir_file, mono=False)
ir_aud.shape
# Out:
# (9, 7998)
